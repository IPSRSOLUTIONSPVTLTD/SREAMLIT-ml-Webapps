# %% [markdown]
# <a href="https://colab.research.google.com/github/Anoop-A-Anto/SREAMLIT-ml-Webapps/blob/main/employee_left_prediction_only.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret -q
# Out:
#      |████████████████████████████████| 81kB 8.9MB/s
#      |████████████████████████████████| 61kB 7.6MB/s
#      |████████████████████████████████| 256kB 31.3MB/s
#      |████████████████████████████████| 1.7MB 47.4MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 14.2MB 213kB/s
#      |████████████████████████████████| 1.4MB 49.1MB/s
#      |████████████████████████████████| 276kB 51.2MB/s
#      |████████████████████████████████| 2.0MB 56.8MB/s
#      |████████████████████████████████| 112kB 39.0MB/s
#      |████████████████████████████████| 6.8MB 37.3MB/s
#      |████████████████████████████████| 174kB 14.4MB/s
#      |████████████████████████████████| 1.1MB 39.8MB/s
#      |████████████████████████████████| 61kB 7.2MB/s
#      |████████████████████████████████| 10.1MB 36.4MB/s
# ...

# %%
from pycaret.classification import load_model,predict_model
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget https://github.com/Anoop-A-Anto/SREAMLIT-ml-Webapps/blob/main/Final_model.pkl

##change url to below form from github files to run

# !wget https://raw.githubusercontent.com/Anoop-A-Anto/SREAMLIT-ml-Webapps/main/Final_model.pkl

# %%
saved_model1 = load_model("/content/Final_model")
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
data_unseen_for_testing=pd.read_csv("/content/unseen-employ.csv")
data_unseen_for_testing.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.89             1.00               5                   224
# 1                0.76             0.89               5                   262
# 2                0.09             0.62               6                   294
# 3                0.45             0.48               2                   158
# 4                0.38             0.55               2                   134
#
#    time_spend_company  Work_accident  promotion_last_5years  department  \
# 0                   5              0                      0       sales
# 1                   5              0                      0       sales
# 2                   4              0                      0  accounting
# 3                   3              0                      0   technical
# 4                   3              0                      0     support
#
#   salary  left
# 0    low     1
# 1    low     1
# 2    low     1
# ...

# %%
data_unseen_for_testing=pd.read_csv("/content/drive/MyDrive/ml_project_test/employee_attrition/employee-dataset-unseen.csv")
data_unseen_for_testing.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.89             1.00               5                   224
# 1                0.76             0.89               5                   262
# 2                0.09             0.62               6                   294
# 3                0.45             0.48               2                   158
# 4                0.38             0.55               2                   134
#
#    time_spend_company  Work_accident  promotion_last_5years  department  \
# 0                   5              0                      0       sales
# 1                   5              0                      0       sales
# 2                   4              0                      0  accounting
# 3                   3              0                      0   technical
# 4                   3              0                      0     support
#
#   salary  left
# 0    low     1
# 1    low     1
# 2    low     1
# ...

# %%
unseen_predictions = predict_model(saved_model1,data=data_unseen_for_testing)
unseen_predictions
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.89             1.00               5                   224
# 1                0.76             0.89               5                   262
# 2                0.09             0.62               6                   294
# 3                0.45             0.48               2                   158
# 4                0.38             0.55               2                   134
#
#    time_spend_company  Work_accident  promotion_last_5years  department  \
# 0                   5              0                      0       sales
# 1                   5              0                      0       sales
# 2                   4              0                      0  accounting
# 3                   3              0                      0   technical
# 4                   3              0                      0     support
#
#   salary  left  Label  Score
# 0    low     1      1   1.00
# ...

# %%
# unseen_predictions = predict_model(saved_model,data=data_unseen_for_testing)
# unseen_predictions
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                 0.89             1.00               5                   224
# 1                 0.76             0.89               5                   262
# 2                 0.09             0.62               6                   294
# 3                 0.45             0.48               2                   158
# 4                 0.38             0.55               2                   134
# 5                 0.39             0.54               2                   132
# 6                 0.11             0.94               6                   286
# 7                 0.81             0.70               6                   161
# 8                 0.10             0.83               6                   295
# 9                 0.40             0.54               2                   137
# 10                0.37             0.57               2                   130
# ...
